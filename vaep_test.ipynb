# %%
import os
import warnings
import pandas as pd
pd.set_option('display.max_columns', None)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.filterwarnings(action="ignore", message="credentials were not supplied. open data access only")
import tqdm
from socceraction.data.statsbomb import StatsBombLoader
import socceraction.spadl as spadl

# %%
SBL = StatsBombLoader(getter="remote", creds={"user": None, "passwd": None})
competitions = SBL.competitions()
set(competitions.competition_name)
# Out:
# {'1. Bundesliga',
#  'African Cup of Nations',
#  'Champions League',
#  'Copa del Rey',
#  "FA Women's Super League",
#  'FIFA U20 World Cup',
#  'FIFA World Cup',
#  'Indian Super league',
#  'La Liga',
#  'Liga Profesional',
#  'Ligue 1',
#  'Major League Soccer',
#  'NWSL',
#  'North American League',
#  'Premier League',
#  'Serie A',
#  'UEFA Euro',
#  'UEFA Europa League',
#  "UEFA Women's Euro",
#  "Women's World Cup"}

# %%
selected_competitions = competitions[
    (competitions.competition_name == "La Liga")
    & (competitions.season_name == "2019/2020")
]
selected_competitions
# Out:
#     season_id  competition_id competition_name country_name  \
# 37         42              11          La Liga        Spain
#
#    competition_gender season_name
# 37               male   2019/2020

# %%
# Get games from all selected competitions
games = pd.concat([
    SBL.games(row.competition_id, row.season_id)
    for row in selected_competitions.itertuples()
])
games[["home_team_id", "away_team_id", "game_date", "home_score", "away_score"]]
# Out:
#     home_team_id  away_team_id           game_date  home_score  away_score
# 0            217           322 2020-02-22 16:00:00           5           0
# 1            217           205 2020-06-16 22:00:00           2           0
# 2            209           217 2020-06-27 17:00:00           2           2
# 3            217           220 2019-12-18 20:00:00           0           0
# 4            217           222 2019-09-24 21:00:00           2           1
# 5            222           217 2020-07-05 22:00:00           1           4
# 6            221           217 2019-11-02 16:00:00           3           1
# 7            217          1043 2019-12-07 21:00:00           5           2
# 8            210           217 2019-12-14 16:00:00           2           2
# 9            217           221 2020-02-02 21:00:00           2           1
# 10           207           217 2020-01-25 16:00:00           2           0
# 11           217           422 2020-07-16 21:00:00           1           2
# 12           206           217 2020-07-19 17:00:00           0           5
# 13           217           215 2020-06-23 22:00:00           1           0
# 14           901           217 2020-07-11 19:30:00           0           1
# 15           217           210 2020-03-07 18:30:00           1           0
# 16           217           214 2020-07-08 22:00:00           1           0
# 17           217           212 2020-06-30 22:00:00           2           2
# 18           217           209 2019-11-09 21:00:00           4           1
# 19           217           901 2019-10-29 21:15:00           5           1
# 20          1043           217 2020-06-13 22:00:00           0           4
# 21           214           217 2020-01-04 21:00:00           2           2
# 22           213           217 2020-06-19 22:00:00           0           0
# 23           220           217 2020-03-01 21:00:00           2           0
# 24           322           217 2019-10-19 13:00:00           0           3
# 25           218           217 2020-02-09 21:00:00           2           3
# 26          1049           217 2019-09-21 21:00:00           2           0
# 27           205           217 2019-11-23 13:00:00           1           2
# 28           217           216 2020-02-15 16:00:00           2           1
# 29           212           217 2019-12-01 21:00:00           0           1
# 30           217           206 2019-12-21 16:00:00           4           1
# 31           217          1049 2020-01-19 21:00:00           1           0
# 32           217           213 2019-10-06 21:00:00           4           0

# %%
games_verbose = tqdm.tqdm(list(games.itertuples()), desc="Loading game data")
teams, players = [], []
actions = {}
for game in games_verbose:
    # load data
    teams.append(SBL.teams(game.game_id))
    players.append(SBL.players(game.game_id))
    events = SBL.events(game.game_id)
    # convert data
    actions[game.game_id] = spadl.statsbomb.convert_to_actions(
        events, 
        home_team_id=game.home_team_id,
        xy_fidelity_version=1,
        shot_fidelity_version=1
    )

teams = pd.concat(teams).drop_duplicates(subset="team_id")
players = pd.concat(players)
# Out:
# Loading game data:   0%|          | 0/33 [00:00<?, ?it/s]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:   3%|▎         | 1/33 [00:44<23:40, 44.40s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:   6%|▌         | 2/33 [01:28<22:58, 44.47s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:   9%|▉         | 3/33 [02:13<22:12, 44.43s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  12%|█▏        | 4/33 [02:58<21:32, 44.56s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  15%|█▌        | 5/33 [03:42<20:47, 44.56s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  18%|█▊        | 6/33 [04:27<20:03, 44.58s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  21%|██        | 7/33 [05:12<19:21, 44.67s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  24%|██▍       | 8/33 [05:56<18:37, 44.71s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  27%|██▋       | 9/33 [06:41<17:50, 44.62s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  30%|███       | 10/33 [07:25<17:06, 44.63s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  33%|███▎      | 11/33 [08:10<16:20, 44.57s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  36%|███▋      | 12/33 [08:55<15:37, 44.66s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  39%|███▉      | 13/33 [09:39<14:52, 44.65s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  42%|████▏     | 14/33 [10:24<14:07, 44.61s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  45%|████▌     | 15/33 [11:08<13:22, 44.59s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  48%|████▊     | 16/33 [11:53<12:38, 44.59s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  52%|█████▏    | 17/33 [12:37<11:52, 44.55s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  55%|█████▍    | 18/33 [13:22<11:08, 44.53s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# ...
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  82%|████████▏ | 27/33 [20:03<04:26, 44.47s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  85%|████████▍ | 28/33 [20:47<03:42, 44.51s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  88%|████████▊ | 29/33 [21:32<02:58, 44.52s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  91%|█████████ | 30/33 [22:16<02:13, 44.53s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  94%|█████████▍| 31/33 [23:01<01:28, 44.47s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data:  97%|█████████▋| 32/33 [23:46<00:44, 44.58s/it]c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:336: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["under_pressure"] = eventsdf["under_pressure"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\data\statsbomb\loader.py:337: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   eventsdf["counterpress"] = eventsdf["counterpress"].fillna(False).astype(bool)
# c:\Users\shrey\Anaconda3\envs\soccer_tda\lib\site-packages\socceraction\spadl\statsbomb.py:74: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   events['extra'].fillna({}, inplace=True)
# Loading game data: 100%|██████████| 33/33 [24:30<00:00, 44.57s/it]

# %%
datafolder = "../data-fifa"

# Create data folder if it doesn't exist
if not os.path.exists(datafolder):
    os.mkdir(datafolder)
    print(f"Directory {datafolder} created.")

spadl_h5 = os.path.join(datafolder, "spadl-statsbomb.h5")

# Store all spadl data in h5-file
with pd.HDFStore(spadl_h5) as spadlstore:
    spadlstore["competitions"] = selected_competitions
    spadlstore["games"] = games
    spadlstore["teams"] = teams
    spadlstore["players"] = players[['player_id', 'player_name', 'nickname']].drop_duplicates(subset='player_id')
    spadlstore["player_games"] = players[['player_id', 'game_id', 'team_id', 'is_starter', 'starting_position_id', 'starting_position_name', 'minutes_played']]
    for game_id in actions.keys():
        spadlstore[f"actions/game_{game_id}"] = actions[game_id]

# %%
pip install matplotsoccer

# %%
with pd.HDFStore(spadl_h5) as spadlstore:
    games = (
        spadlstore["games"]
        .merge(spadlstore["competitions"], how='left')
        .merge(spadlstore["teams"].add_prefix('home_'), how='left')
        .merge(spadlstore["teams"].add_prefix('away_'), how='left'))
    # Select England vs Belgium game at World Cup
    game = games[(games.competition_name == "FIFA World Cup") 
                  & (games.away_team_name == "England")
                  & (games.home_team_name == "Belgium")]
    game_id = game.game_id.values[0]
    actions = (
        spadlstore[f"actions/game_{game_id}"]
        .merge(spadl.actiontypes_df(), how="left")
        .merge(spadl.results_df(), how="left")
        .merge(spadl.bodyparts_df(), how="left")
        .merge(spadlstore["players"], how="left")
        .merge(spadlstore["teams"], how="left")
    )

# use nickname if available else use full name
actions["player_name"] = actions[["nickname", "player_name"]].apply(lambda x: x.iloc[0] if x.iloc[0] else x.iloc[1], axis=1)
del actions['nickname']
actions[:5]
